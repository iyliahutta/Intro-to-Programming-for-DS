# %%
#Create a program for food ordering system

from pickle import TRUE


print('Welcome to Food Order')
name = input('How may I address you?')
print('Hi ' + name)

#assigning variables
#item1, item2, item3 = 'Burger', 'Coke', 'Fries' #to store multiple variables with shorthand
#item4 = item5 = 'Fish and Chips'

menu = [
    'Burger',
    'Coke',
    'Fries',
    'Fish and Chips',
    'Salad'
]

#to print multiple strings together
#use f (formatting) function
#or .format function

print('You may order the following:')
#print(f'{item1} {item2} {item3} {item4} {item5}')

#for stepper_variable in sequence_variable:
#   something_you_want_to_do

for item in menu:
    print(item) #tab after a for or while loop is important in python!
    #print('[]') #every item that is tabbed in will be executed under the iteration
#print('[]') #without a tab, the code will not be under loop iteration

choice = input('Enter the name of the item:')

#using the membership operator 'in' to test for membershoip in sequence
#print(choice in menu)

#if-else statements for conditionals
if choice in menu:
    print('Good choice')
else:
    print('Sorry ' + choice + ' does not exist')
# Out:
# Welcome to Food Order
# Hi
# You may order the following:
# Burger
# Coke
# Fries
# Fish and Chips
# Salad
# Sorry  does not exist

# %%
#Create a program for food ordering system

from pickle import TRUE


print('Welcome to Food Order')
name = input('How may I address you?')
print('Hi ' + name)

#assigning variables
#item1, item2, item3 = 'Burger', 'Coke', 'Fries' #to store multiple variables with shorthand
#item4 = item5 = 'Fish and Chips'

menu = [
    'Burger',
    'Coke',
    'Fries',
    'Fish and Chips',
    'Salad'
]

#to print multiple strings together
#use f (formatting) function
#or .format function

print('You may order the following:')
#print(f'{item1} {item2} {item3} {item4} {item5}')

#for stepper_variable in sequence_variable:
#   something_you_want_to_do

#using enumerate to retrieve index of list
for number, item in enumerate(menu):
    print(f'[{number}] {item}')

choice = int(input('Enter the number of the item:'))

#using the membership operator 'in' to test for membershoip in sequence
#print(choice in menu)

#if-else statements for conditionals
#if choice in menu:
if choice >= 0 and choice < len(menu):
    print('Good choice')
else:
    print(f'Sorry {choice} does not exist')
# Out:
# Welcome to Food Order
# Hi iylia
# You may order the following:
# [0] Burger
# [1] Coke
# [2] Fries
# [3] Fish and Chips
# [4] Salad
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [17], line 46
#      44     print('Good choice')
#      45 else:
# ---> 46     print(f'Sorry {menu[choice]} does not exist')
#
# IndexError: list index out of range

# %%
#Compound assignment operators

a,b,c,d,e, x = 1, 10, 3, 100, 23, 5 

a += x   # equivalent to a = a+x, hence, a becomes 6

b -= x    # equivalent to b = b-x, hence, b becomes 5

c *= x    # equivalent to c = c times x, hence,c becomes 15

d /= x   # equivalent to d = d divide by x, hence,d becomes 20.0

e %= x  # equivalent to e = remainder of e divide by x, hence,e becomes

# %%
#Create a program for food ordering system

from curses.ascii import isalpha
from pickle import TRUE

def create_order_item(menu_index, menu, prices):
  #print price of item
    print(f'{menu[menu_index]} costs ${prices[menu_index]:.2f}')
    
    #prompt user for quantity
    quantity = int(input(f'How many of {menu[menu_index]} would you like?:'))

    #calculate price with quantity and store
    subtotal = quantity*prices[menu_index]

    #display subtotal
    print(f'{quantity} X {menu[menu_index]} would cost a total of ${subtotal:.2f}\n')

    return[menu_index, quantity, subtotal]

print('Welcome to Food Order\n')
name = input('How may I address you?')
print('Hi ' + name)

#assigning variables
#item1, item2, item3 = 'Burger', 'Coke', 'Fries' #to store multiple variables with shorthand
#item4 = item5 = 'Fish and Chips'

menu = [
    'Burger',
    'Coke',
    'Fries',
    'Fish and Chips',
    'Salad'
]

prices = [
    3.50,
    1.50,
    2,
    5,
    3
]

#to print multiple strings together
#use f (formatting) function
#or .format function

print('\nYou may order the following:')
#print(f'{item1} {item2} {item3} {item4} {item5}')

#for stepper_variable in sequence_variable:
#   something_you_want_to_do

#using enumerate to retrieve index of list
for number, item in enumerate(menu):
    print(f'[{number}] {item}')

print('[Q] to checkout')

order = []

while True:
    choice = input('Enter the number of the item:')

    if choice.upper() == 'Q':
        break;
    elif choice.isalpha(): #error message and re-enter if user inputs a letter and not a number
        choice = input('That was an invalid input. Please key in the number of an item or "Q" to checkout:')

    menu_index = int(choice)

    #using the membership operator 'in' to test for membershoip in sequence
    #print(choice in menu)

    #if-else statements for conditionals
    #if choice in menu:
    if menu_index >= 0 and menu_index < len(menu):
        print('\nGood choice')

        #print price of item
        #print(f'{menu[menu_index]} costs ${prices[menu_index]:.2f}')
        
        #prompt user for quantity
        #quantity = int(input(f'How many of {menu[menu_index]} would you like?:'))

        #calculate price with quantity and store
        #subtotal = quantity*prices[menu_index]

        #display subtotal
        #print(f'{quantity} X {menu[menu_index]} would cost a total of ${subtotal:.2f}')

        #use function
        order_item = create_order_item(menu_index, menu, prices)

        add order item to list
        order.append(order_item)

        #for y in order:
        #    if order[y][0] == order_item[0]:
        #        for i in range(len(order)):
        #            order[i][0] = order_item[0]
        #            order[i][1] = order[i][1] + order_item[1]
        #            order[i][2] = order[i][2] + order_item[2]
        #    else:
        #        exit()
        #
        #order.append(order_item)

    else:
        print(f'\nSorry {menu_index} does not exist')

#print the order, each item with name, quantity and subtotal
total = 0

print('Your order and total is:\n')

for item in order:
    item_Index = item[0]
    qty = item[1]
    sub_total = item[2]

    print(f'{menu[item_Index]} X {qty}: ${sub_total:.2f}')

    total = total + sub_total #total += sub_total

#print grand total
print(f'Total: ${total:.2f}')
# Out:
# Welcome to Food Order
#
# Hi iyli
#
# You may order the following:
# [0] Burger
# [1] Coke
# [2] Fries
# [3] Fish and Chips
# [4] Salad
# [Q] to checkout
#
# Good choice
# Fries costs $2.00
# 3 X Fries would cost a total of $6.00
#
#
# Good choice
# Salad costs $3.00
# 3 X Salad would cost a total of $9.00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [48], line 100
#      96 #add order item to list
#      97 #order.append(order_item)
#      99 for y in order:
# --> 100     if order[y][0] == order_item[0]:
#     101         for i in range(len(order)):
#     102             order[i][0] = order_item[0]
#
# TypeError: list indices must be integers or slices, not list

# %%
# %reset
